# %%
import pandas as pd
data=pd.read_excel("C:\\Users\\hp\\Desktop\\Bijouterie 2.xlsx")
data.head()
# Out:
#    ID  carat      cut color clarity  depth  table  price     x     y     z
# 0   1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
data.isna().sum()
# Out:
# ID         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
data=data.drop(columns='ID',axis=1)

# %%
data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
data.shape
# Out:
# (53940, 10)

# %%
data.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
data=data.loc[(data[['x','y','z']]!=0).all(axis=1)]

# %%
data.shape
# Out:
# (53920, 10)

# %%
data.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53920.000000  53920.000000  53920.000000  53920.000000  53920.000000
# mean       0.797698     61.749514     57.456834   3930.993231      5.731627
# std        0.473795      1.432331      2.234064   3987.280446      1.119423
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    949.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5323.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53920.000000  53920.000000
# mean       5.734887      3.540046
# std        1.140126      0.702530
# min        3.680000      1.070000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
import matplotlib.pyplot as plt
data.hist(figsize=(20,15),bins=30)
plt.show()

# %%
data.query("carat>2") # ou bien on utilise loc[]
# data.loc[data['carat']>2]
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 12246   2.06  Premium     J      I1   61.2   58.0   5203  8.10  8.07  4.95
# 13002   2.14     Fair     J      I1   69.4   57.0   5405  7.74  7.70  5.36
# 13118   2.15     Fair     J      I1   65.5   57.0   5430  8.01  7.95  5.23
# 13757   2.22     Fair     J      I1   66.7   56.0   5607  8.04  8.02  5.36
# 13991   2.01     Fair     I      I1   67.4   58.0   5696  7.71  7.64  5.17
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 27741   2.15    Ideal     G     SI2   62.6   54.0  18791  8.29  8.35  5.21
# 27742   2.04  Premium     H     SI1   58.1   60.0  18795  8.37  8.28  4.84
# 27744   2.29  Premium     I     SI1   61.8   59.0  18797  8.52  8.45  5.24
# 27746   2.07    Ideal     G     SI2   62.5   55.0  18804  8.20  8.13  5.11
# 27749   2.29  Premium     I     VS2   60.8   60.0  18823  8.50  8.47  5.16
#
# [1883 rows x 10 columns]

# %%
import seaborn as sns
sns.pairplot(data,diag_kind='kde')
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import matplotlib.pyplot as plt
sns.scatterplot(x=data.carat , y=data.price)
#plt.title("nuage de points ")
#plt.figure(figsize=(10,10))
plt.show()

# %%
data.query("price>17000 or carat<1.4")
#data.loc[(data['price']>17000) | (data['carat']<1.4)]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [48164 rows x 10 columns]

# %%
#data.loc[(data['carat']<1.5) & (data['price']>17000)]
data.query("carat<1 or price >17000 ")
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [35591 rows x 10 columns]

# %%
plt.figure(figsize = (8,5))
sns.heatmap(data.corr(),annot = True, cmap = 'coolwarm' )
# Out:
# <Axes: >

# %%
correl_matrix=data.corr()
correl_matrix["price"].sort_values(ascending=False)
# Out:
# price    1.000000
# carat    0.921592
# x        0.887231
# z        0.868206
# y        0.867864
# table    0.127245
# depth   -0.010729
# Name: price, dtype: float64

# %%
print(   data.cut.unique()          ) #mais c'est mieux de faire
print(     data["color"].unique()   )
print(  data['clarity'].unique() )
# Out:
# ['Ideal' 'Premium' 'Good' 'Very Good' 'Fair']
# ['E' 'I' 'J' 'H' 'F' 'G' 'D']
# ['SI2' 'SI1' 'VS1' 'VS2' 'VVS2' 'VVS1' 'I1' 'IF']

# %%
I1 < SI2 < SI1 < VS2 <VS1 < VVS2 < VVS1 < IF
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14772\3346197066.py in <module>
# ----> 1 I1 < SI2 < SI1 < VS2 <VS1 < VVS2 < VVS1 < IF
#
# NameError: name 'I1' is not defined

# %%
print(data['cut'].unique())
# Out:
# ['Ideal' 'Premium' 'Good' 'Very Good' 'Fair']

# %%
import numpy as np
M=[(1,2),(2,8),(6,3)]
L=np.array(M)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53920 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53920 non-null  float64
#  1   cut      53920 non-null  object
#  2   color    53920 non-null  object
#  3   clarity  53920 non-null  object
#  4   depth    53920 non-null  float64
#  5   table    53920 non-null  float64
#  6   price    53920 non-null  int64
#  7   x        53920 non-null  float64
#  8   y        53920 non-null  float64
#  9   z        53920 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 6.5+ MB

# %%
correl_matrix=data.corr()
correl_matrix["price"].sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: >

# %%
data.query("price>4400")
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 8400    1.07    Premium     G     SI2   62.0   59.0   4401  6.54  6.50  4.04
# 8401    0.90      Ideal     F     SI1   60.7   57.0   4401  6.21  6.25  3.78
# 8402    0.90  Very Good     G     SI1   62.9   54.0   4401  6.14  6.16  3.87
# 8403    1.06      Ideal     H     SI2   60.1   59.0   4401  6.65  6.63  3.99
# 8404    1.03      Ideal     I     SI1   63.3   57.0   4401  6.37  6.46  4.06
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 27745   2.00  Very Good     H     SI1   62.8   57.0  18803  7.95  8.00  5.01
# 27746   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20  8.13  5.11
# 27747   1.51      Ideal     G      IF   61.7   55.0  18806  7.37  7.41  4.56
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90  7.97  5.04
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823  8.50  8.47  5.16
#
# [17417 rows x 10 columns]

# %%
data.query("cut=='Ideal' and price>10000")
# Out:
#        carat    cut color clarity  depth  table  price     x     y     z
# 21928   1.70  Ideal     J     VS2   60.5   58.0  10002  7.73  7.74  4.68
# 21929   1.03  Ideal     E    VVS2   60.6   59.0  10003  6.50  6.53  3.95
# 21931   1.25  Ideal     F     VS2   61.6   55.0  10006  6.93  6.96  4.28
# 21936   1.05  Ideal     F    VVS2   60.5   55.0  10011  6.67  6.58  4.01
# 21937   1.60  Ideal     J     VS1   62.0   53.0  10011  7.57  7.56  4.69
# ...      ...    ...   ...     ...    ...    ...    ...   ...   ...   ...
# 27735   1.60  Ideal     F     VS1   62.0   56.0  18780  7.47  7.52  4.65
# 27738   2.05  Ideal     G     SI1   61.9   57.0  18787  8.10  8.16  5.03
# 27741   2.15  Ideal     G     SI2   62.6   54.0  18791  8.29  8.35  5.21
# 27746   2.07  Ideal     G     SI2   62.5   55.0  18804  8.20  8.13  5.11
# 27747   1.51  Ideal     G      IF   61.7   55.0  18806  7.37  7.41  4.56
#
# [1769 rows x 10 columns]

# %%
sns.boxplot(x=data.cut , y=data.price ,data=data)
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %%
list_varCategor = data.select_dtypes(include=['object']).columns.tolist()

for i in list_varCategor :
    sns.catplot(x=i,y=data.price,kind="box",aspect=3,data=data)

# %%
##Converting Categorial to numeric values

data.cut.replace({'Fair':1 , 'Good':2, 'Very Good':3,'Premium':4 , 'Ideal':5},inplace=True)
data.color.replace({'D':1,'E':2,'F':3,'G':4,'H':5,'I':6,'J':7},inplace=True)
data.clarity.replace({'I1':1,'SI2':2,'SI1':3 ,'VS2':4,'VS1':5,'VVS2':6,'VVS1':7,'IF':8},inplace=True)
data.head()
# Out:
#    carat  cut  color  clarity  depth  table  price     x     y     z
# 0   0.23    5      2        2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    4      2        3   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23    2      2        5   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    4      6        4   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31    2      7        2   63.3   58.0    335  4.34  4.35  2.75

# %%
X=data.drop(columns='price',axis=1)
Y=data['price']

# %%
#SplitData

from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.33,random_state=34)

# %%
# Regression Lineaire

import sklearn.linear_model as ls
regressor=ls.LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
print(regressor.score(X_train,Y_train))
print(regressor.score(X_test,Y_test))
# Out:
# 0.9066339821180031
# 0.9082552447192367

# %%
from sklearn.metrics import r2_score
Y_pred= regressor.predict(X_train)
R2=r2_score(Y_pred,Y_train)
print(R2)
Ypred=regressor.predict(X_test)
R22=r2_score(Ypred,Y_test)
print(R22)
#sns.scatterplot(x=X_train['carat'] , y=Y_train , color='red',marker='*')
#sns.scatterplot(x=X_train['carat'] , y=Y_pred , color='blue',marker='*')
sns.scatterplot(x=Y_train,y=Y_pred)
sns.scatterplot(x=Y_test,y=Ypred,color=c[8])
# Out:
# 0.8970190620211669
# 0.9006310547958181
# <Axes: xlabel='price'>

# %%
new_diamond = [0.23, 5, 2, 1, 61.5, 55,3.95, 3.98,2.43]
prediction = regressor.predict([new_diamond])[0]
print(prediction)
# Out:
# -1384.925602576438
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
data.query("price==15000")
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z
# 25884    1.6    5      4        4   61.9   56.0  15000  7.53  7.47  4.64

# %%
print("R carré de training = {:.2%} ".format(regressor.score(X_train,Y_train)))
print("R carré de test    = {:.2%} ".format(regressor.score(X_test,Y_test)))
# Out:
# R carré de training = 90.66%
# R carré de test    = 90.83%

# %%
c=sns.color_palette('colorblind')

# %%
# TREEDECISION

import sklearn.tree as st
tree=st.DecisionTreeRegressor(random_state=34)
tree.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor(random_state=34)

# %%
#print("R square de training = {:.2%} ".format(tree.score(X_train,Y_train)))
print("R square de training ={:.2%} ".format(tree.score(X_train,Y_train)))
print("R square de test     = {:.2%}".format(tree.score(X_test,Y_test)))
# Out:
# R square de training =100.00%
# R square de test     = 96.41%

# %%
ypredt1=tree.predict(X_train)
ypredt2=tree.predict(X_test)
sns.scatterplot(x=Y_train,y=ypredt1,color='red')
sns.scatterplot(x=Y_test,y=ypredt2,color='blue')
# Out:
# <Axes: xlabel='price'>

# %%
diamo=[1.6,5,4,4,61.9,56,7.53,7.47,4.64]
pr=tree.predict([diamo])[0]
print(pr)
# Out:
# 15395.0
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
# RANDOM FOREST

import sklearn.ensemble as se
RF=se.RandomForestRegressor(n_estimators=100,random_state=34)
RF.fit(X_train,Y_train)
# Out:
# RandomForestRegressor(random_state=34)

# %%
print("R2 training = {:.2%} ".format(RF.score(X_train,Y_train)))
print("R2 test     = {:.2%} ".format(RF.score(X_test,Y_test)))
# Out:
# R2 training = 99.74%
# R2 test     = 98.10%

# %%
print(RF.predict([diamo]))
# Out:
# [13550.17]
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
prdFR1=RF.predict(X_train)
prdFR2=RF.predict(X_test)
sns.scatterplot(x=Y_train,y=prdFR1)
sns.scatterplot(x=Y_test,y=prdFR2,color='red')
# Out:
# <Axes: xlabel='price'>

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
# Calculer les différentes métriques d'évaluation
rmse = mean_squared_error(Y_test, ypredt2, squared=False)
mae = mean_absolute_error(Y_test, ypredt2)
mape = mean_absolute_percentage_error(Y_test, ypredt2)

# Afficher les métriques d'évaluation TreeDecision

print("Erreur quadratique moyenne (RMSE) :", rmse)
print("Erreur absolue moyenne (MAE) :", mae)
print("Erreur absolue pourcentage (MAPE) :", mape)
# Out:
# Erreur quadratique moyenne (RMSE) : 752.8031939639379
# Erreur absolue moyenne (MAE) : 363.69961784871305
# Erreur absolue pourcentage (MAPE) : 0.08496992603319603

# %%
rmse = mean_squared_error(Y_test, prdFR2, squared=False)
mae = mean_absolute_error(Y_test, prdFR2)
r_squared = r2_score(Y_test, prdFR2)
mape = mean_absolute_percentage_error(Y_test, prdFR2)

# Afficher les métriques d'évaluation RandomForest

print("Erreur quadratique moyenne (RMSE) :", rmse)
print("Erreur absolue moyenne (MAE) :", mae)
print("Coefficient de détermination (R²) :", r_squared)
print("Erreur absolue pourcentage (MAPE) :", mape)
# Out:
# Erreur quadratique moyenne (RMSE) : 546.6823019841358
# Erreur absolue moyenne (MAE) : 271.949347859364
# Coefficient de détermination (R²) : 0.981045504485954
# Erreur absolue pourcentage (MAPE) : 0.06503313087133328

# %%
rmse = mean_squared_error(Y_test, Ypred, squared=False)
mae = mean_absolute_error(Y_test, Ypred)
r_squared = r2_score(Y_test, Ypred)
mape = mean_absolute_percentage_error(Y_test, Ypred)

# Afficher les métriques d'évaluation Régression linéaire

print("Erreur quadratique moyenne (RMSE) :", rmse)
print("Erreur absolue moyenne (MAE) :", mae)
print("Coefficient de détermination (R²) :", r_squared)
print("Erreur absolue pourcentage (MAPE) :", mape)
# Out:
# Erreur quadratique moyenne (RMSE) : 1202.7338190115668
# Erreur absolue moyenne (MAE) : 792.252128027168
# Coefficient de détermination (R²) : 0.9082552447192367
# Erreur absolue pourcentage (MAPE) : 0.43164948275258486

# %%
fig=plt.figure()
axs=fig.subplot_mosaic("""
                        AAA
                        BCC
                        BCC
                        """)
